# %%
import pandas as pd

df = pd.read_csv('kosakata_jepang_5000_kana.csv')
df
# Out:
#         kategori                                             jepang  \
# 0          angka                 いち（れい7873）（れい8668）（れい7939）（れい4143）
# 1     kata kerja                                        たべる（れい9165）
# 2       keluarga  おとうさん（れい2679）（れい8651）（れい9288）（れい6967）（れい6280）（...
# 3          frase  いえにいきます（れい5374）（れい8579）（れい7615）（れい5351）（れい5708...
# 4          frase   たのしいをします（れい4611）（れい3060）（れい5022）（れい8061）（れい6536）
# ...          ...                                                ...
# 5195  perkenalan  こんにちは（れい4257）（れい5386）（れい3504）（れい4613）（れい9561）（...
# 5196       frase           せんせいをみます（れい4657）（れい5889）（れい3535）（れい4292）
# 5197       frase                            たべるをみます（れい9751）（れい2572）
# 5198    keluarga  ちち（れい6514）（れい3287）（れい2982）（れい2771）（れい8749）（れい9...
# 5199     sekolah       せんせい（れい5012）（れい8359）（れい7932）（れい1514）（れい7590）
#
#                                                  romaji  \
# 0                              ichi-7873-8668-7939-4143
# ...

# %%
df.columns
# Out:
# Index(['kategori', 'jepang', 'romaji', 'arti', 'tipe', 'catatan'], dtype='object')
